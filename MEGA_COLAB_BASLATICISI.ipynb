# %% [markdown]
# # 🚀 LEVH-İ MAHFUZ V5 + ANTI-GRAVITY (V.2 SENTEZİ)
#
# Aşağıdaki hücreye (kod bloğuna) tıkla ve **Oynat (Play/Run)** düğmesine bas. Bu hücre senin en güncel GitHub (Copilot YZ) depondaki devasa kuantum simülasyonunu bulut ortamına çekecek, ufak renk hatalarını otomatik onaracak ve devasa şifreleri saniyeler içinde ekrana dökecektir!

# %%
# 1. Github'dan En Güncel Faz-2 Kuantum Sentez Kodlarını Çek
# !rm -rf S-M-LASYON_11
# !git clone https://github.com/Soldiers33/S-M-LASYON_11.git
# %cd S-M-LASYON_11

# 2. Python Veri Analizi Kütüphanelerini Kur
# !pip install pandas numpy scipy > /dev/null

# 3. Ajanın Bıraktığı Ufak Kod Hatalarını (Bug) Otomatik Cerrahi Onarımla Düzelt
# !sed -i 's/Colors.MAGENTA/Colors.PURPLE/g' simulasyon_11.py
# !sed -i 's/self.const.KAILASH_LATITUDE/self.const.KAILASH_LAT/g' kar_topu_v5_v2_synthesis.py

# 4. Devasa Simülasyonu Ateşle!
# !python simulasyon_11.py
